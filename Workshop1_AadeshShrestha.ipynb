# %% [markdown]
# Name: Aadesh Shrestha
#
# Student ID: 2418263

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Understanding Image as a Matrix.

# %%
from PIL import Image
image_coloured = Image.open("/Lenna_(test_image).png")
display(image_coloured)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
image_grayed = image_coloured.convert('L')
print( " Image Format : " , image_grayed . format )
print( " Image Size : " , image_grayed . size )
print( " Image Mode : " , image_grayed . mode )
# Out:
#  Image Format :  None
#  Image Size :  (512, 512)
#  Image Mode :  L

# %%
print("Image Format:", image_coloured.format)
print("Image Size:", image_coloured.size)
print("Image Mode:", image_coloured.mode)
# Out:
# Image Format: PNG
# Image Size: (512, 512)
# Image Mode: RGB

# %%
# Get the size (width , height ) and channels (RGB)
width , height = image_grayed . size
channels = len( image_grayed . getbands () ) # For RGB , it will be 3
print ( f" Image shape (RGB): ({ height } , { width } , { channels})")
image_size_grayed = width * height *1
print ( f" Image size (RGB): { image_size_grayed }")
# Out:
#  Image shape (RGB): (512 , 512 , 1)
#  Image size (RGB): 262144

# %%
# Get the size (width , height ) and channels (RGB)
width , height = image_coloured . size
channels = len( image_coloured . getbands () ) # For RGB, it will be 3
print ( f" Image shape (RGB): ({ height } , { width } , { channels})")
image_size_colored = width * height *3
print ( f" Image size (RGB): { image_size_colored }")
# Out:
#  Image shape (RGB): (512 , 512 , 3)
#  Image size (RGB): 786432

# %%
import numpy as np

# Convert the Pillow image to a NumPy array
image_array_coloured = np.array(image_coloured)

# Display the shape of the NumPy array (height, width, channels)
print("Shape of the image array:", image_array_coloured.shape)
# Out:
# Shape of the image array: (512, 512, 3)

# %%
import numpy as np

# Convert the Pillow image to a NumPy array
image_array_grayed = np.array(image_grayed)

# Display the shape of the NumPy array (height, width)
print("Shape of the image array:", image_array_grayed.shape)
# Out:
# Shape of the image array: (512, 512)

# %%
import numpy as np
import matplotlib.pyplot as plt


# Convert the Pillow image to a NumPy array
image_array_colored = np.array(image_coloured)

# Display shape
print("Shape of the image array:", image_array_colored.shape)

#  Red Channel (index 0)
red_channel = image_array_colored[:, :, 0]
print("Red Channel:")
print(red_channel)
display(red_channel)

#  Green Channel (index 1)
green_channel = image_array_colored[:, :, 1]
print("Green Channel:")
print(green_channel)
display(green_channel)
# Out:
# Shape of the image array: (512, 512, 3)
# Red Channel:
# [[226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  ...
#  [ 84  84  92 ... 173 172 177]
#  [ 82  82  96 ... 179 181 185]
#  [ 82  82  96 ... 179 181 185]]
# array([[226, 226, 223, ..., 230, 221, 200],
#        [226, 226, 223, ..., 230, 221, 200],
#        [226, 226, 223, ..., 230, 221, 200],
#        ...,
#        [ 84,  84,  92, ..., 173, 172, 177],
#        [ 82,  82,  96, ..., 179, 181, 185],
#        [ 82,  82,  96, ..., 179, 181, 185]], dtype=uint8)
# Green Channel:
# [[137 137 137 ... 148 130  99]
#  [137 137 137 ... 148 130  99]
#  [137 137 137 ... 148 130  99]
#  ...
#  [ 18  18  27 ...  73  68  62]
#  [ 22  22  32 ...  70  71  74]
#  [ 22  22  32 ...  70  71  74]]
# array([[137, 137, 137, ..., 148, 130,  99],
#        [137, 137, 137, ..., 148, 130,  99],
#        [137, 137, 137, ..., 148, 130,  99],
#        ...,
#        [ 18,  18,  27, ...,  73,  68,  62],
# ...

# %%
#  Blue Channel
blue_channel = image_array_colored[:, :, 2]  # Blue channel
print(blue_channel)
display(blue_channel)
# Out:
# [[125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  ...
#  [ 60  60  58 ...  84  76  79]
#  [ 57  57  62 ...  79  81  81]
#  [ 57  57  62 ...  79  81  81]]
# array([[125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        ...,
#        [ 60,  60,  58, ...,  84,  76,  79],
#        [ 57,  57,  62, ...,  79,  81,  81],
#        [ 57,  57,  62, ...,  79,  81,  81]], dtype=uint8)

# %%
# Compute covariance matrix
cov_matrix = np . cov ( centered_data , rowvar = False )

# %%
# Sample Implementation:

# Accessing a specific row - 100th row
row_100 = image_array_coloured[100, :, :]
print("100th row shape:", row_100.shape)

# Accessing a specific column - 50th column
col_50 = image_array_coloured[:, 50, :]
print("50th column shape:", col_50.shape)

# Accessing a specific pixel (row 10, col 20)
pixel = image_array_coloured[10, 20, :]  # Gets RGB values at (10, 20)
print("Pixel at (10, 20):", pixel)
# Out:
# 100th row shape: (512, 3)
# 50th column shape: (512, 3)
# Pixel at (10, 20): [222 134 115]

# %%
# Define the cropping box (left, upper, right, lower)
left, upper, right, lower = 100, 50, 200, 150

# Crop the image
cropped_image = image_coloured.crop((left, upper, right, lower))

# Display the cropped image
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
import numpy as np
from PIL import Image

# Create a NumPy array (Here, we use a dummy array for illustration)
image_array = np.zeros((100, 100, 3), dtype=np.uint8)  # Black image

# Convert the NumPy array back to a Pillow Image object
image_from_array = Image.fromarray(image_array)

# Display the image
image_from_array.show()

# Optionally, save the image to a file
image_from_array.save("output_image.jpg")

from google.colab import files
files.download("/content/output_image.jpg")

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Load image and convert to grayscale
image = Image.open("Lenna_(test_image).png").convert("L")

# Convert to NumPy array
image_array = np.array(image)

# Get image dimensions
height, width = image_array.shape
print("Image dimensions:", height, "x", width)

# Reshape the image into a 2D array (each row as a pixel row)
# For PCA, each row can be treated as an observation
data = image_array.reshape(height, width)
print("Data shape for PCA:", data.shape)
# Out:
# Image dimensions: 512 x 512
# Data shape for PCA: (512, 512)

# %%
# Compute the mean of each column ( feature )
mean = np . mean ( data , axis =0)
# Subtract mean to center the data
centered_data = data - mean

# %%
# Compute eigenvalues and eigenvectors
eigenvalues , eigenvectors = np . linalg . eigh ( cov_matrix )
# Sort eigenvalues and corresponding eigenvectors in descending order
sorted_indices = np . argsort ( eigenvalues ) [:: -1]
eigenvalues = eigenvalues [ sorted_indices ]
eigenvectors = eigenvectors [: , sorted_indices ]

# %%
# Plot the explained variance ratio
explained_variance_ratio = eigenvalues / np .sum ( eigenvalues )
plt . plot ( np . cumsum ( explained_variance_ratio ) )
plt . title (" Cumulative Explained Variance ")
plt . xlabel (" Number of Components ")
plt . ylabel (" Cumulative Explained Variance ")
plt . grid ( True )
plt . show ()

# %%
k = 50 # Choose k principal components
principal_components = eigenvectors [: , : k ]

# %%
# Project the data onto the principal components
compressed_data = np . dot ( centered_data , principal_components )

# %%
decompressed_data = np.dot(compressed_data, principal_components.T) + mean
plt . figure ( figsize =(12 , 6) )
# Original Image
plt . subplot (1 , 3 , 1)
plt . imshow ( image_array , cmap ="gray")
plt . title (" Original Image ")
plt . axis ("off")
# Compressed Representation
plt . subplot (1 , 3 , 2)
plt . imshow ( compressed_data , cmap ="gray", aspect ="auto")
plt . title ( f" Compressed Image (k={k})")
plt . axis ("off")
# Decompressed Image
plt . subplot (1 , 3 , 3)
plt . imshow ( decompressed_data , cmap ="gray")
plt . title (" Decompressed Image ")
plt . axis ("off")
plt . tight_layout ()
plt . show ()
